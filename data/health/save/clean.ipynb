# %%
import pandas as pd


csv_path = "cardiac_recordings.csv"

df = pd.read_csv(csv_path)
# Out:
#    recording_id patient_number encounter_number recording_date  \
# 0    CRD-410031      PAT-31162       ENC-000004     2022-06-21
# 1    CRD-410019      PAT-31162       ENC-000004     2022-06-21
# 2    CRD-410025      PAT-31040       ENC-000007     2017-03-16
# 3    CRD-410016      PAT-31115       ENC-000017     2025-09-11
# 4    CRD-410014      PAT-31233       ENC-000033     2023-04-25
# 5    CRD-410038      PAT-31065       ENC-000038     2024-06-12
# 6    CRD-410005      PAT-31065       ENC-000038     2024-06-12
# 7    CRD-410022      PAT-31037       ENC-000053     2019-12-01
# 8    CRD-410001      PAT-31221       ENC-000061     2024-04-03
# 9    CRD-410021      PAT-31119       ENC-000076     2024-03-13
# 10   CRD-410040      PAT-31183       ENC-000085     2020-07-30
# 11   CRD-410018      PAT-31099       ENC-000093     2018-09-17
# 12   CRD-410015      PAT-31226       ENC-000953     2021-07-19
# 13   CRD-410030      PAT-31141       ENC-000565     2023-02-28
# ...
